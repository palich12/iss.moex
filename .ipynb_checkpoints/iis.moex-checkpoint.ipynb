# %%
from urllib.request import urlopen
import json
import pandas as pd

# %%
response = urlopen("https://iss.moex.com/iss/engines/stock/markets/shares/boards/TQBR/securities.json")
json_data = response.read().decode('utf-8', 'replace')

# %%
d = json.loads(json_data)
d["securities"]["data"]
# Out:
# [['ABIO',
#   'TQBR',
#   'iАРТГЕН ао',
#   84.64,
#   10,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ПАО "Артген"',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   87.12,
#   'SUR',
#   '2025-04-29',
#   92645451,
#   'RU000A0JNAB6',
#   'ARTGEN ao',
#   '1-01-08902-A',
#   85.28,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['ABRD',
#   'TQBR',
#   'АбрауДюрсо',
#   187.4,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Абрау-Дюрсо ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.2,
#   189,
#   'SUR',
#   '2025-04-29',
#   98000184,
#   'RU000A0JS5T7',
#   'Abrau-Durso ao',
#   '1-02-12500-A',
#   187.4,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['AFKS',
#   'TQBR',
#   'Система ао',
#   15.42,
#   100,
#   0.09,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   'АФК "Система" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.001,
#   15.616,
#   'SUR',
#   '2025-04-29',
#   9650000000,
#   'RU000A0DQZE3',
#   'AFK Sistema',
#   '1-05-01669-A',
#   15.48,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['AFLT',
#   'TQBR',
#   'Аэрофлот',
#   70.79,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Аэрофлот-росс.авиалин(ПАО)ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   71.61,
#   'SUR',
#   '2025-04-29',
#   3975771215,
#   'RU0009062285',
#   'Aeroflot',
#   '1-01-00010-A',
#   71.01,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['AGRO',
#   'TQBR',
#   'AGRO-гдр',
#   1083.8,
#   1,
#   0,
#   'N',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ГДР ROS AGRO PLC ORD SHS',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.2,
#   1083.8,
#   'USD',
#   '2025-04-29',
#   0,
#   'US7496552057',
#   'GDR ROS AGRO PLC ORD SHS',
#   None,
#   1085.2,
#   'SUR',
#   'D',
#   3,
#   '2025-05-02'],
#  ['AKRN',
#   'TQBR',
#   'Акрон',
#   16034,
#   1,
#   5,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Акрон ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   2,
#   16288,
#   'SUR',
#   '2025-04-29',
#   36757156,
#   'RU0009028674',
#   'Acron',
#   '1-03-00207-A',
#   16034,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['ALRS',
#   'TQBR',
#   'АЛРОСА ао',
#   49.19,
#   10,
#   0.5,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'АЛРОСА ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   50.06,
#   'SUR',
#   '2025-04-29',
#   7364965630,
#   'RU0007252813',
#   'ALROSA ao',
#   '1-03-40046-N',
#   49.81,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['AMEZ',
#   'TQBR',
#   'АшинскийМЗ',
#   68.05,
#   100,
#   1,
#   'N',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Ашинский метзавод ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   68.05,
#   'SUR',
#   '2025-04-29',
#   498454822,
#   'RU000A0B88G6',
#   'Ashinckiy metzavod PAO',
#   '1-03-45219-D',
#   68.05,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['APRI',
#   'TQBR',
#   'АПРИ',
#   12.964,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   'АПРИ',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.002,
#   12.926,
#   'SUR',
#   '2025-04-29',
#   1115439217,
#   'RU000A108LJ5',
#   'APRI',
#   '1-01-12464-K',
#   12.964,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['APTK',
#   'TQBR',
#   'Аптеки36и6',
#   10.392,
#   10,
#   0.64,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   'ПАО "Аптечная сеть 36,6" ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.002,
#   10.842,
#   'SUR',
#   '2025-04-29',
#   7630433826,
#   'RU0008081765',
#   'Apteki 36,6',
#   '1-01-07335-A',
#   10.7,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['AQUA',
#   'TQBR',
#   'ИНАРКТИКА',
#   651.5,
#   1,
#   100,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ПАО ИНАРКТИКА',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   655.5,
#   'SUR',
#   '2025-04-29',
#   87876649,
#   'RU000A0JQTS3',
#   'INARCTIKA',
#   '1-01-04461-D',
#   652.5,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['ARSA',
#   'TQBR',
#   'Арсагера',
#   10.9,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'УК Арсагера ПАО-ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   11.05,
#   'SUR',
#   '2025-04-29',
#   123817165,
#   'RU000A0JP0Q7',
#   'UK Arsagera',
#   '1-01-03163-D',
#   10.9,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['ASSB',
#   'TQBR',
#   'АстрЭнСб',
#   1.89,
#   1000,
#   0.007,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   '"Астраханская ЭСК" ПАО',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.005,
#   1.855,
#   'SUR',
#   '2025-04-29',
#   773900078,
#   'RU000A0D8MM8',
#   'Astrakhan Energo Sbyt',
#   '1-01-55064-E',
#   1.885,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['ASTR',
#   'TQBR',
#   'Астра ао',
#   401.9,
#   1,
#   0.05,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Группа Астра ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   404.95,
#   'SUR',
#   '2025-04-29',
#   210000000,
#   'RU000A106T36',
#   'Astra Group',
#   '1-01-01286-G',
#   403.8,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['AVAN',
#   'TQBR',
#   'Авангрд-ао',
#   733,
#   1,
#   30,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'АКБ "АВАНГАРД" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   1,
#   739,
#   'SUR',
#   '2025-04-29',
#   80700000,
#   'RU000A0DM7B3',
#   'AKB "AVANGARD"',
#   '10102879B',
#   733,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['BANE',
#   'TQBR',
#   'Башнефт ао',
#   2003,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Башнефть АНК ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   2028.5,
#   'SUR',
#   '2025-04-29',
#   147846489,
#   'RU0007976957',
#   'Bashneft ANK ao',
#   '1-01-00013-A',
#   2007,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['BANEP',
#   'TQBR',
#   'Башнефт ап',
#   1190,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Башнефть АНК ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   1194,
#   'SUR',
#   '2025-04-29',
#   29788012,
#   'RU0007976965',
#   'Bashneft ANK ap',
#   '2-01-00013-A',
#   1186,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['BELU',
#   'TQBR',
#   'НоваБев ао',
#   484.5,
#   1,
#   100,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'НоваБев Групп ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   490,
#   'SUR',
#   '2025-04-29',
#   126400000,
#   'RU000A0HL5M1',
#   'NovaBev Group ao',
#   '1-01-55052-E',
#   486.5,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['BISVP',
#   'TQBR',
#   'БашИнСв ап',
#   9.19,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Башинформсвязь(ПАО) ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   9.28,
#   'SUR',
#   '2025-04-29',
#   36165270,
#   'RU0009100176',
#   'BashInformSvyaz ap',
#   '2-01-00011-A',
#   9.19,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['BLNG',
#   'TQBR',
#   'Белон ао',
#   15.14,
#   100,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Белон ОАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   15.4,
#   'SUR',
#   '2025-04-29',
#   1150000000,
#   'RU000A0J2QG8',
#   'Belon ao',
#   '1-06-10167-F',
#   15.14,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['BRZL',
#   'TQBR',
#   'БурЗолото',
#   1803,
#   1,
#   0.025,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Бурятзолото ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   1,
#   1810,
#   'SUR',
#   '2025-04-29',
#   7027270,
#   'RU0009288658',
#   'Buryatzoloto ao',
#   '1-06-20577-F',
#   1803,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['BSPB',
#   'TQBR',
#   'БСП ао',
#   408.54,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ПАО "Банк "Санкт-Петербург" ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   409.45,
#   'SUR',
#   '2025-04-29',
#   457544031,
#   'RU0009100945',
#   'BSP',
#   '10300436B',
#   409.5,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['BSPBP',
#   'TQBR',
#   'БСП ап',
#   66.5,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Банк Санкт-Петербург ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   67.35,
#   'SUR',
#   '2025-04-29',
#   20100000,
#   'RU000A0JP0U9',
#   'BSP ap',
#   '20100436B',
#   66.5,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['CARM',
#   'TQBR',
#   'СТГ',
#   1.497,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   4,
#   'СТГ ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.0005,
#   1.505,
#   'SUR',
#   '2025-04-29',
#   2203330301,
#   'RU000A105NV2',
#   'STG',
#   '1-01-03536-G',
#   1.5055,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['CBOM',
#   'TQBR',
#   'МКБ ао',
#   7.792,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   '"МКБ" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.001,
#   7.924,
#   'SUR',
#   '2025-04-29',
#   33429709866,
#   'RU000A0JUG31',
#   'MKB ao',
#   '10101978B',
#   7.86,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['CHGZ',
#   'TQBR',
#   'РН-ЗапСиб',
#   91,
#   10,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'РН-Западная Сибирь ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.2,
#   92,
#   'SUR',
#   '2025-04-29',
#   26771420,
#   'RU0009082291',
#   'RN-Western Siberia ao',
#   '1-01-00185-A',
#   91,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['CHKZ',
#   'TQBR',
#   'ЧКПЗ ао',
#   17700,
#   1,
#   200,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   '"ЧКПЗ" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   50,
#   18100,
#   'SUR',
#   '2025-04-29',
#   600216,
#   'RU000A0JNST0',
#   'CKPZ',
#   '1-03-45058-D',
#   17750,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['CHMF',
#   'TQBR',
#   'СевСт-ао',
#   1033.6,
#   1,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Северсталь (ПАО)ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.2,
#   1049.6,
#   'SUR',
#   '2025-04-29',
#   837718660,
#   'RU0009046510',
#   'Severstal - ao',
#   '1-02-00143-A',
#   1040,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['CHMK',
#   'TQBR',
#   'ЧМК ао',
#   5330,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   '"ЧМК" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   5,
#   5390,
#   'SUR',
#   '2025-04-29',
#   3161965,
#   'RU0007665170',
#   'CMK',
#   '1-01-00080-A',
#   5330,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['CNRU',
#   'TQBR',
#   'ЦИАН',
#   549.2,
#   1,
#   0.0337,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'МКПАО "ЦИАН"',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.2,
#   561.4,
#   'SUR',
#   '2025-04-29',
#   77670490,
#   'RU000A10ANA1',
#   'IPJSC CIAN',
#   '1-01-16918-A',
#   549.2,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['CNTL',
#   'TQBR',
#   'Телеграф',
#   10.58,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   '"Центральный Телеграф" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   10.68,
#   'SUR',
#   '2025-04-29',
#   166167000,
#   'RU0007665147',
#   'Centrlnyi Telegraf',
#   '1-03-00327-A',
#   10.58,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['CNTLP',
#   'TQBR',
#   'Телеграф-п',
#   7.46,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   '"Центральный Телеграф" ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   7.52,
#   'SUR',
#   '2025-04-29',
#   55389000,
#   'RU0007665139',
#   'Centrlnyi Telegraf ap',
#   '2-03-00327-A',
#   7.46,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['DATA',
#   'TQBR',
#   'iАренадата',
#   127.96,
#   1,
#   0.05,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Группа Аренадата',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   128.54,
#   'SUR',
#   '2025-04-29',
#   209160464,
#   'RU000A108ZR8',
#   'Arenadata Group',
#   '1-01-87685-H',
#   128.94,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['DELI',
#   'TQBR',
#   'iКаршеринг',
#   168.3,
#   1,
#   0.000625,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Каршеринг Руссия ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   170,
#   'SUR',
#   '2025-04-29',
#   175849057,
#   'RU000A107J11',
#   'Carsharing Russia',
#   '1-01-16750-A',
#   170.15,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['DIAS',
#   'TQBR',
#   'iДиасофт',
#   3315,
#   1,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Диасофт ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   3318.5,
#   'SUR',
#   '2025-04-29',
#   10500000,
#   'RU000A107ER5',
#   'Diasoft',
#   '1-01-84777-H',
#   3307,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['DIOD',
#   'TQBR',
#   'ЗаводДИОД',
#   10.74,
#   100,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Завод ДИОД ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   11.02,
#   'SUR',
#   '2025-04-29',
#   91500000,
#   'RU000A0JQWC1',
#   'Zavod DIOD ao',
#   '1-03-06923-A',
#   10.74,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['DVEC',
#   'TQBR',
#   'ДЭК ао',
#   2.159,
#   1000,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   '"ДЭК" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.001,
#   2.172,
#   'SUR',
#   '2025-04-29',
#   17223107804,
#   'RU000A0JP2W1',
#   'DEC',
#   '1-01-55275-E',
#   2.159,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['DZRD',
#   'TQBR',
#   'ДонскЗР',
#   3870,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Донской завод радиодеталей ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   5,
#   3915,
#   'SUR',
#   '2025-04-29',
#   343407,
#   'RU000A0JQW11',
#   'DZRD ao',
#   '1-01-02677-A',
#   3870,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['DZRDP',
#   'TQBR',
#   'ДонскЗР п',
#   2650,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Донской завод радиодеталей ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   10,
#   2670,
#   'SUR',
#   '2025-04-29',
#   114469,
#   'RU000A0JQW29',
#   'DZRD pref.',
#   '2-01-02677-A',
#   2650,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['EELT',
#   'TQBR',
#   'ЕвроЭлтех',
#   11.5,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   '"ЕвропЭлектротехника" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   11.48,
#   'SUR',
#   '2025-04-29',
#   551813000,
#   'RU000A0JWW54',
#   'European Eltech',
#   '1-01-83993-H',
#   11.5,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['ELFV',
#   'TQBR',
#   'ЭЛ5Энер ао',
#   0.4974,
#   1000,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   4,
#   '"ЭЛ5-Энерго" ПАО',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.0002,
#   0.5,
#   'SUR',
#   '2025-04-29',
#   35371898370,
#   'RU000A0F5UN3',
#   'El5-Ener',
#   '1-01-50077-A',
#   0.5008,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['ELMT',
#   'TQBR',
#   'Элемент',
#   0.1326,
#   1000,
#   0.05,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   5,
#   'Элемент',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   5e-05,
#   0.13355,
#   'SUR',
#   '2025-04-29',
#   469725539040,
#   'RU000A102093',
#   'ELEMENT',
#   '1-01-16673-A',
#   0.1339,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['ENPG',
#   'TQBR',
#   'ЭН+ГРУП ао',
#   421.85,
#   1,
#   7e-05,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'МКПАО ЭН+ ГРУП ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   430.95,
#   'USD',
#   '2025-04-29',
#   638848896,
#   'RU000A100K72',
#   'EN+ GROUP IPJSC ORD SHS',
#   '1-01-16625-A',
#   428.15,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['ETLN',
#   'TQBR',
#   'ETLN-гдр',
#   61.58,
#   1,
#   0,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ГДР ETALON GROUP PLC ORD SHS',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   61.78,
#   'USD',
#   '2025-04-29',
#   0,
#   'US29760G1031',
#   'GDR ETALON GROUP PLC ORD SHS',
#   None,
#   61.64,
#   'SUR',
#   'D',
#   3,
#   '2025-05-02'],
#  ['EUTR',
#   'TQBR',
#   'ЕвроТранс',
#   122.95,
#   1,
#   0.05,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ЕвроТранс ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   125.45,
#   'SUR',
#   '2025-04-29',
#   159148665,
#   'RU000A1002V2',
#   'EvroTrans',
#   '1-01-80110-H',
#   123.75,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['FEES',
#   'TQBR',
#   'Россети',
#   0.07032,
#   10000,
#   0.5,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   5,
#   '"ФСК - Россети" ПАО',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   2e-05,
#   0.07118,
#   'SUR',
#   '2025-04-29',
#   2113460101477,
#   'RU000A0JPNN9',
#   'FGC ROSSETI',
#   '1-01-65018-D',
#   0.07046,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['FESH',
#   'TQBR',
#   'ДВМП ао',
#   63.39,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ДВ морское пароходство ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   63.19,
#   'SUR',
#   '2025-04-29',
#   2951250000,
#   'RU0008992318',
#   'DVMP ao',
#   '1-03-00032-A',
#   63.26,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['FIXP',
#   'TQBR',
#   'FIXP-гдр',
#   157.2,
#   1,
#   0,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ГДР FixPrice Group PLC ORD SHS',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.1,
#   158.1,
#   'USD',
#   '2025-04-29',
#   0,
#   'US33835G2057',
#   'GDR FixPrice Group PLC ORD SHS',
#   None,
#   158.1,
#   'SUR',
#   'D',
#   3,
#   '2025-05-02'],
#  ['FLOT',
#   'TQBR',
#   'Совкомфлот',
#   88.22,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Совкомфлот ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   89.45,
#   'SUR',
#   '2025-04-29',
#   2374993901,
#   'RU000A0JXNU8',
#   'Sovcomflot',
#   '1-01-10613-A',
#   89.1,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['GAZA',
#   'TQBR',
#   'ГАЗ ао',
#   671,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'ГАЗ ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   1,
#   673,
#   'SUR',
#   '2025-04-29',
#   18520260,
#   'RU0009034268',
#   'Gaz ao',
#   '1-01-00029-A',
#   671,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['GAZAP',
#   'TQBR',
#   'ГАЗ ап',
#   427.5,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ГАЗ ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   429,
#   'SUR',
#   '2025-04-29',
#   1453500,
#   'RU000A0ZYHF5',
#   'Gaz (pref)',
#   '2-02-00029-A',
#   427.5,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['GAZC',
#   'TQBR',
#   'ГАЗКОН-ао',
#   659,
#   10,
#   10,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'ГАЗКОН (ПАО) ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   1,
#   301,
#   'SUR',
#   '2025-04-29',
#   225381601,
#   'RU000A0JQG86',
#   'Gazkon ao',
#   '1-01-09870-A',
#   659,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['GAZP',
#   'TQBR',
#   'ГАЗПРОМ ао',
#   149.25,
#   10,
#   5,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   '"Газпром" (ПАО) ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   151.52,
#   'SUR',
#   '2025-04-29',
#   23673512900,
#   'RU0007661625',
#   'Gazprom',
#   '1-02-00028-A',
#   151,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['GAZS',
#   'TQBR',
#   'ГАЗ-сервис',
#   839,
#   10,
#   10,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'ГАЗ-сервис (ПАО) ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   1,
#   300,
#   'SUR',
#   '2025-04-29',
#   206508967,
#   'RU000A0JQG78',
#   'Gaz-servis ao',
#   '1-01-09871-A',
#   839,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['GAZT',
#   'TQBR',
#   'ГАЗ-Тек ао',
#   1739,
#   10,
#   100,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ГАЗ-Тек ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   81,
#   'SUR',
#   '2025-04-29',
#   471428300,
#   'RU000A0JS199',
#   'GAZ-Tek PAO ao',
#   '1-01-12996-A',
#   1739,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['GCHE',
#   'TQBR',
#   'ЧеркизГ-ао',
#   3822,
#   1,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Группа Черкизово ПАО-ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   1,
#   3873,
#   'SUR',
#   '2025-04-29',
#   42222042,
#   'RU000A0JL4R1',
#   'Cherkizovo Group ao',
#   '1-02-10797-A',
#   3822,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['GECO',
#   'TQBR',
#   'iГЕНЕТИКО',
#   28.65,
#   10,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ЦГРМ ГЕНЕТИКО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   28.78,
#   'SUR',
#   '2025-04-29',
#   83000000,
#   'RU000A105BN4',
#   'GENETICO',
#   '1-01-87198-H',
#   28.65,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['GEMA',
#   'TQBR',
#   'iММЦБ ао',
#   122.2,
#   10,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ПАО ММЦБ ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.1,
#   125.6,
#   'SUR',
#   '2025-04-29',
#   14929920,
#   'RU000A100GC7',
#   'IMCB PJSC',
#   '1-01-85932-H',
#   122.2,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['GEMC',
#   'TQBR',
#   'МКПАО ЮМГ',
#   747.7,
#   1,
#   0.03721404,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Юнайтед Медикал Груп ПАО',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.1,
#   754.4,
#   'SUR',
#   '2025-04-29',
#   90000000,
#   'RU000A107JE2',
#   'IPJSC UMG',
#   '1-01-16774-A',
#   752,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['GMKN',
#   'TQBR',
#   'ГМКНорНик',
#   113.62,
#   10,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ГМК "Нор.Никель" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   115.1,
#   'SUR',
#   '2025-04-29',
#   15286339700,
#   'RU0007288411',
#   'NorNickel GMK',
#   '1-01-40155-F',
#   114.54,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['GTRK',
#   'TQBR',
#   'ГТМ ао',
#   226.3,
#   10,
#   100,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ПАО "ГТМ" ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.1,
#   233.1,
#   'SUR',
#   '2025-04-29',
#   58462120,
#   'RU000A0ZYD22',
#   'GTM',
#   '1-01-84907-H',
#   226.9,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['HEAD',
#   'TQBR',
#   'Хэдхантер',
#   3162,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'МКПАО Хэдхантер',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   1,
#   3190,
#   'SUR',
#   '2025-04-29',
#   47184918,
#   'RU000A107662',
#   'IPJSC Headhunter',
#   '1-01-16755-A',
#   3212,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['HIMCP',
#   'TQBR',
#   'Химпром ап',
#   22.64,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Химпром ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   22.72,
#   'SUR',
#   '2025-04-29',
#   229631402,
#   'RU0009099006',
#   'Himprom ap',
#   '2-01-55076-D',
#   22.64,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['HNFG',
#   'TQBR',
#   'ХЭНДЕРСОН',
#   615,
#   1,
#   50,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ХЭНДЕРСОН ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.1,
#   621.9,
#   'SUR',
#   '2025-04-29',
#   40444445,
#   'RU000A106XF2',
#   'HENDERSON',
#   '1-01-03109-G',
#   614.8,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['HYDR',
#   'TQBR',
#   'РусГидро',
#   0.4746,
#   1000,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   4,
#   'ПАО "РусГидро"',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.0001,
#   0.4796,
#   'SUR',
#   '2025-04-29',
#   444793377038,
#   'RU000A0JPKH7',
#   'RusGidro',
#   '1-01-55038-E',
#   0.478,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['IGST',
#   'TQBR',
#   'Ижсталь2ао',
#   6140,
#   1,
#   1000,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Ижсталь ПАО ао 2в.',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   20,
#   6200,
#   'SUR',
#   '2025-04-29',
#   800729,
#   'RU0002155292',
#   'Izhstal 2ao',
#   '1-02-30078-D',
#   6160,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['IGSTP',
#   'TQBR',
#   'Ижсталь ап',
#   4450,
#   1,
#   1000,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Ижсталь ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   10,
#   4450,
#   'SUR',
#   '2025-04-29',
#   266910,
#   'RU0002155300',
#   'Izhstal ap',
#   '2-02-30078-D',
#   4450,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['INGR',
#   'TQBR',
#   'ИНГРАД ао',
#   1764,
#   1,
#   1000,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'ИНГРАД ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   2,
#   1768,
#   'SUR',
#   '2025-04-29',
#   41220793,
#   'RU000A0DJ9B4',
#   'INGRAD',
#   '1-01-50020-A',
#   1764,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['IRAO',
#   'TQBR',
#   'ИнтерРАОао',
#   3.553,
#   100,
#   2.809767,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   4,
#   '"Интер РАО" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.0005,
#   3.575,
#   'SUR',
#   '2025-04-29',
#   104400000000,
#   'RU000A0JPNM1',
#   'Inter RAO ao',
#   '1-04-33498-E',
#   3.5675,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['IRKT',
#   'TQBR',
#   'Яковлев-3',
#   33.56,
#   100,
#   3,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   '"Яковлев" ПАО ак.об.-3',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   34.48,
#   'SUR',
#   '2025-04-29',
#   12051279624,
#   'RU0006752979',
#   'Yakovlev-3',
#   '1-03-00040-A',
#   33.94,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['IVAT',
#   'TQBR',
#   'iИВА',
#   147,
#   1,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ПАО ИВА ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   147.05,
#   'SUR',
#   '2025-04-29',
#   100000000,
#   'RU000A108GD8',
#   'PJSC IVA',
#   '1-01-10876-P',
#   146.35,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['JNOS',
#   'TQBR',
#   'Славн-ЯНОС',
#   16.5,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Славнефть-ЯНОС (ПАО) ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   16.65,
#   'SUR',
#   '2025-04-29',
#   932654723,
#   'RU0009100895',
#   'Slavneft-JANOS',
#   '1-01-00199-A',
#   16.55,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['JNOSP',
#   'TQBR',
#   'Слав-ЯНОСп',
#   10.62,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Славнефть-ЯНОС (ПАО) ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   10.7,
#   'SUR',
#   '2025-04-29',
#   310884574,
#   'RU0009101927',
#   'Slavneft-JANOS (pref)',
#   '2-01-00199-A',
#   10.62,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['KAZT',
#   'TQBR',
#   'Куйбазот',
#   479.2,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Куйбышевазот ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.2,
#   482,
#   'SUR',
#   '2025-04-29',
#   234147999,
#   'RU000A0B9BV2',
#   'Kuib.Azot ao',
#   '1-01-00067-A',
#   479.2,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['KAZTP',
#   'TQBR',
#   'Куйбазот-п',
#   490,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Куйбышевазот ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   492.5,
#   'SUR',
#   '2025-04-29',
#   3696506,
#   'RU000A0B9BW0',
#   'Kuibishevazot ap',
#   '2-01-00067-A',
#   490,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['KBSB',
#   'TQBR',
#   'ТНСэКубань',
#   450,
#   10,
#   0.56,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ТНС энерго Кубань ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   442,
#   'SUR',
#   '2025-04-29',
#   17869440,
#   'RU000A0JNJ11',
#   'TNS energo Kuban Company',
#   '1-01-55218-E',
#   449,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['KCHE',
#   'TQBR',
#   'КамчатЭ ао',
#   0.431,
#   10000,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   'Камчатскэнерго ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.001,
#   0.432,
#   'SUR',
#   '2025-04-29',
#   58294409860,
#   'RU0006753498',
#   'Kamchatskenergo',
#   '1-02-00235-A',
#   0.431,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['KCHEP',
#   'TQBR',
#   'КамчатЭ ап',
#   0.725,
#   10000,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   'Камчатскэнерго ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.005,
#   0.725,
#   'SUR',
#   '2025-04-29',
#   183062052,
#   'RU0006753480',
#   'Kamchatskenergo (pref)',
#   '2-02-00235-A',
#   0.725,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['KGKC',
#   'TQBR',
#   'КурганГКао',
#   42.2,
#   10,
#   7.2,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Курганская генер.комп.ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.2,
#   42.6,
#   'SUR',
#   '2025-04-29',
#   122453406,
#   'RU000A0JP120',
#   'Kurganskaja Gener.Kompanija',
#   '1-01-55226-E',
#   42.2,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['KGKCP',
#   'TQBR',
#   'КурганГКап',
#   50.8,
#   10,
#   7.2,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Курганская генер. комп. ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.2,
#   50.6,
#   'SUR',
#   '2025-04-29',
#   14393052,
#   'RU000A0JP138',
#   'Kurganskaja Gener.Kompanija ap',
#   '2-01-55226-E',
#   50.8,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['KLSB',
#   'TQBR',
#   'КалужскСК',
#   23.28,
#   100,
#   0.2,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ао"Калужская сбыт.комп."ПАО',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   23.49,
#   'SUR',
#   '2025-04-29',
#   91487347,
#   'RU000A0DKZK3',
#   'Kalugsk. Sbyt. Company ao',
#   '1-01-65057-D',
#   23.28,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['KLVZ',
#   'TQBR',
#   'Кристалл',
#   3.818,
#   100,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   'Алкогольная Группа Кристалл',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.002,
#   3.82,
#   'SUR',
#   '2025-04-29',
#   921052700,
#   'RU000A107KX0',
#   'KLVZ KRISTALL',
#   '1-01-05421-G',
#   3.818,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['KMAZ',
#   'TQBR',
#   'КАМАЗ',
#   107.7,
#   10,
#   50,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'КАМАЗ ПАО',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.1,
#   109.1,
#   'SUR',
#   '2025-04-29',
#   707229559,
#   'RU0008959580',
#   'KAMAZ',
#   '1-08-55010-D',
#   108.7,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['KMEZ',
#   'TQBR',
#   'КМЗ',
#   1196,
#   1,
#   250,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Ковровский механический завод',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   2,
#   1212,
#   'SUR',
#   '2025-04-29',
#   3764600,
#   'RU0006753613',
#   'Kovrov Mech. Zavod',
#   '1-02-05376-A',
#   1196,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['KOGK',
#   'TQBR',
#   'КоршГОК ао',
#   39000,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Коршуновский ГОК ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   200,
#   39400,
#   'SUR',
#   '2025-04-29',
#   250126,
#   'RU0002155359',
#   'Korshunovskii GOK',
#   '1-01-20992-F',
#   39000,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['KRKN',
#   'TQBR',
#   'СаратНПЗ',
#   9150,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Саратовский НПЗ ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   50,
#   9100,
#   'SUR',
#   '2025-04-29',
#   748012,
#   'RU0009100408',
#   'Saratovskiy NPZ ao',
#   '1-01-00248-A',
#   9150,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['KRKNP',
#   'TQBR',
#   'СаратНПЗ-п',
#   8200,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Саратовский НПЗ ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   20,
#   8200,
#   'SUR',
#   '2025-04-29',
#   249337,
#   'RU0009100416',
#   'Saratovskiy NPZ ap',
#   '2-01-00248-A',
#   8200,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['KRKOP',
#   'TQBR',
#   'ТКЗКК ап',
#   12.74,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ТКЗ Красный котельщик ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   12.9,
#   'SUR',
#   '2025-04-29',
#   71086000,
#   'RU0009098131',
#   'TKZ Krasny Kotelshchik ap',
#   '2-01-30301-E',
#   12.74,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['KROT',
#   'TQBR',
#   'КрасОкт-ао',
#   1575,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   '"КрасныйОктябрь" ПАО - ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   1,
#   1603,
#   'SUR',
#   '2025-04-29',
#   9217583,
#   'RU0008913850',
#   'KrasnyiOctyabr',
#   '1-02-00060-A',
#   1575,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['KROTP',
#   'TQBR',
#   'КрасОкт-1п',
#   486,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'КрасныйОктябрь-1п',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   1,
#   499,
#   'SUR',
#   '2025-04-29',
#   1474549,
#   'RU0008913868',
#   'KrasnyiOctabr-1(pr)',
#   '2-01-00060-A',
#   486,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['KRSB',
#   'TQBR',
#   'Красэсб ао',
#   16,
#   100,
#   0.02,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Красноярскэнергосбыт ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   16.1,
#   'SUR',
#   '2025-04-29',
#   596039612,
#   'RU000A0HMLY1',
#   'Krashojarskenergosbyt',
#   '1-01-55147-E',
#   16,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['KRSBP',
#   'TQBR',
#   'Красэсб ап',
#   15.92,
#   100,
#   0.02,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Красноярскэнергосбыт ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   16.08,
#   'SUR',
#   '2025-04-29',
#   168993328,
#   'RU000A0HMLZ8',
#   'Krashojarskenergosbyt pref.',
#   '2-01-55147-E',
#   15.96,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['KUZB',
#   'TQBR',
#   'КузнецкийБ',
#   0.0342,
#   10000,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   5,
#   'Банк "Кузнецкий" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   5e-05,
#   0.0346,
#   'SUR',
#   '2025-04-29',
#   22503490875,
#   'RU000A0JSQ66',
#   'Bank "Kuzneckiy"',
#   '10100609B',
#   0.0342,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['KZOS',
#   'TQBR',
#   'ОргСинт ао',
#   78.9,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ПАО "Органический синтез" ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.1,
#   82.4,
#   'SUR',
#   '2025-04-29',
#   1785114000,
#   'RU0009089825',
#   'PAO Organicheskiy Sintez ao',
#   '1-02-55245-D',
#   78.9,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['KZOSP',
#   'TQBR',
#   'ОргСинт ап',
#   20.91,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ПАО "Органический синтез" ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   21.24,
#   'SUR',
#   '2025-04-29',
#   119596000,
#   'RU0006753456',
#   'PAO Organicheskiy Sintez ap',
#   '2-02-55245-D',
#   20.91,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['LEAS',
#   'TQBR',
#   'Европлан',
#   632.6,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ПАО «ЛК «Европлан»',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.1,
#   636.4,
#   'SUR',
#   '2025-04-29',
#   120000000,
#   'RU000A0ZZFS9',
#   'Europlan',
#   '1-01-16419-A',
#   631.9,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['LENT',
#   'TQBR',
#   'Лента ао',
#   1484.5,
#   1,
#   0.0912632,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Лента МКПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   1476,
#   'SUR',
#   '2025-04-29',
#   115985197,
#   'RU000A102S15',
#   'Lenta IPJSC ORD SHS',
#   '1-01-16686-A',
#   1481.5,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['LIFE',
#   'TQBR',
#   'Фармсинтез',
#   3.67,
#   100,
#   5,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   'Фармсинтез ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.005,
#   3.715,
#   'SUR',
#   '2025-04-29',
#   440394854,
#   'RU000A0JR514',
#   'Farmsintez ao',
#   '1-02-09669-J',
#   3.67,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['LKOH',
#   'TQBR',
#   'ЛУКОЙЛ',
#   6725,
#   1,
#   0.025,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'НК ЛУКОЙЛ (ПАО) - ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   6797,
#   'SUR',
#   '2025-04-29',
#   692865762,
#   'RU0009024277',
#   'LUKOIL',
#   '1-01-00077-A',
#   6760,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['LMBZ',
#   'TQBR',
#   'Ламбумиз',
#   488,
#   1,
#   0.025,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Ламбумиз',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   500,
#   'SUR',
#   '2025-04-29',
#   20752219,
#   'RU000A108ZX6',
#   'Lambumiz',
#   '1-01-09188-H',
#   488,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['LNZL',
#   'TQBR',
#   'Лензолото',
#   12540,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   '"Лензолото" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   10,
#   12590,
#   'SUR',
#   '2025-04-29',
#   1140300,
#   'RU000A0JP1N2',
#   'Lenzoloto',
#   '1-02-40433-N',
#   12540,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['LNZLP',
#   'TQBR',
#   'Лензол. ап',
#   1775,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   '"Лензолото" ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   5,
#   1790,
#   'SUR',
#   '2025-04-29',
#   347700,
#   'RU000A0JP1P7',
#   'Lenzoloto pref.',
#   '2-02-40433-N',
#   1775,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['LPSB',
#   'TQBR',
#   'ЛЭСК ао',
#   62.15,
#   100,
#   0.22,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Липецкая энергосбыт.ком.ОАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   62.15,
#   'SUR',
#   '2025-04-29',
#   155521950,
#   'RU000A0D8MR7',
#   'LESK ao',
#   '1-01-65097-D',
#   62.15,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['LSNG',
#   'TQBR',
#   'РСетиЛЭ',
#   14.07,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Россети Ленэнерго ПАО-ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   14.17,
#   'SUR',
#   '2025-04-29',
#   8523785320,
#   'RU0009034490',
#   'Rosseti LenEnrg',
#   '1-01-00073-A',
#   14.07,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['LSNGP',
#   'TQBR',
#   'РСетиЛЭ-п',
#   205.25,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Россети Ленэнерго ПАО-ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   206.1,
#   'SUR',
#   '2025-04-29',
#   93264311,
#   'RU0009092134',
#   'Rosseti LenEnrg (pref)',
#   '2-01-00073-A',
#   205.25,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['LSRG',
#   'TQBR',
#   'ЛСР ао',
#   780.2,
#   1,
#   0.25,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Группа ЛСР ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.2,
#   781.6,
#   'SUR',
#   '2025-04-29',
#   103030215,
#   'RU000A0JPFP0',
#   'LSR',
#   '1-01-55234-E',
#   783,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['LVHK',
#   'TQBR',
#   'Левенгук',
#   29.5,
#   100,
#   10,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Левенгук ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   29.55,
#   'SUR',
#   '2025-04-29',
#   52940000,
#   'RU000A0JT7Y2',
#   'Levenguk ao',
#   '1-01-04329-D',
#   29.5,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['MAGE',
#   'TQBR',
#   'МагадЭн ао',
#   3.13,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   '"Магаданэнерго" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   3.14,
#   'SUR',
#   '2025-04-29',
#   463838268,
#   'RU0006758919',
#   'Magadanenergo ao',
#   '1-01-00254-A',
#   3.09,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['MAGEP',
#   'TQBR',
#   'МагадЭн ап',
#   2.23,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   '"Магаданэнерго" ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   2.29,
#   'SUR',
#   '2025-04-29',
#   145673254,
#   'RU0006758893',
#   'Magadanenergo ap',
#   '2-01-00254-A',
#   2.23,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['MAGN',
#   'TQBR',
#   'ММК',
#   33.99,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   '"Магнитогорск.мет.комб" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.005,
#   34.16,
#   'SUR',
#   '2025-04-29',
#   11174330000,
#   'RU0009084396',
#   'MMK',
#   '1-03-00078-A',
#   34.14,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['MBNK',
#   'TQBR',
#   'МТС Банк',
#   1260,
#   1,
#   500,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'МТС-Банк ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   1261,
#   'SUR',
#   '2025-04-29',
#   34629063,
#   'RU000A0JRH43',
#   'MTS Bank',
#   '10102268B',
#   1235,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['MDMG',
#   'TQBR',
#   'MDMG-ао',
#   992.8,
#   1,
#   7.16872,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'МКПАО «МД Медикал Груп»',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.1,
#   993.3,
#   'SUR',
#   '2025-04-29',
#   75125010,
#   'RU000A108KL3',
#   'MD Medical Group IPJSC',
#   '1-01-16802-A',
#   992,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['MFGS',
#   'TQBR',
#   'Мегион-ао',
#   354,
#   10,
#   25,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ао "Славнефть-Мегионнефтегаз"',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   1,
#   356,
#   'SUR',
#   '2025-04-29',
#   99474705,
#   'RU0009011126',
#   'Megion',
#   '1-03-00149-A',
#   354,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['MFGSP',
#   'TQBR',
#   'Мегион-ап',
#   230.5,
#   10,
#   25,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ап Мегионнефтегаз',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   231.5,
#   'SUR',
#   '2025-04-29',
#   33056875,
#   'RU0009011134',
#   'Megion (pref)',
#   '2-03-00149-A',
#   230.5,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['MGKL',
#   'TQBR',
#   'МГКЛ',
#   2.4865,
#   100,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   4,
#   'МГКЛ ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.0005,
#   2.5215,
#   'SUR',
#   '2025-04-29',
#   1268545000,
#   'RU000A0JVJQ8',
#   'MGKL',
#   '1-01-11915-A',
#   2.5165,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['MGNT',
#   'TQBR',
#   'Магнит ао',
#   4467,
#   1,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   '"Магнит" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   4594.5,
#   'SUR',
#   '2025-04-29',
#   101911355,
#   'RU000A0JKQU8',
#   'Magnit',
#   '1-01-60525-P',
#   4556,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['MGNZ',
#   'TQBR',
#   'СМЗ-ао',
#   7440,
#   1,
#   0.25,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Соликамский магн.завод(ОАО)ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   10,
#   7330,
#   'SUR',
#   '2025-04-29',
#   398272,
#   'RU0009100911',
#   'SMZ',
#   '1-01-00283-A',
#   7440,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['MGTS',
#   'TQBR',
#   'МГТС-5ао',
#   1180,
#   1,
#   40,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'ПАО "МГТС" ао (5 в)',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   5,
#   1160,
#   'SUR',
#   '2025-04-29',
#   79708751,
#   'RU0009036461',
#   'MGTS-5',
#   '1-05-00083-A',
#   1180,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['MGTSP',
#   'TQBR',
#   'МГТС-4ап',
#   840,
#   1,
#   40,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'ПАО "МГТС" ап (4 в)',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   2,
#   840,
#   'SUR',
#   '2025-04-29',
#   15514042,
#   'RU0009036479',
#   'MGTS-4',
#   '2-04-00083-A',
#   840,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['MISB',
#   'TQBR',
#   'ТНСэнМарЭл',
#   47.8,
#   100,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ТНС энерго Марий Эл ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.1,
#   48.2,
#   'SUR',
#   '2025-04-29',
#   121847780,
#   'RU000A0D8K33',
#   'TNS energo Mariy El ao',
#   '1-01-50086-A',
#   47.8,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['MISBP',
#   'TQBR',
#   'ТНСэМаЭл-п',
#   45.3,
#   100,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ТНС энерго Марий Эл ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.1,
#   45.9,
#   'SUR',
#   '2025-04-29',
#   10652220,
#   'RU000A0D8K41',
#   'TNS energo Mariy El (pref)',
#   '2-01-50086-A',
#   45.5,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['MOEX',
#   'TQBR',
#   'МосБиржа',
#   199.6,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ПАО Московская Биржа',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   201.17,
#   'SUR',
#   '2025-04-29',
#   2276401458,
#   'RU000A0JR4A1',
#   'MoscowExchange',
#   '1-05-08443-H',
#   200.05,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['MRKC',
#   'TQBR',
#   'РоссЦентр',
#   0.5542,
#   1000,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   4,
#   'ПАО "Россети Центр" ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.0002,
#   0.5598,
#   'SUR',
#   '2025-04-29',
#   42217941468,
#   'RU000A0JPPL8',
#   'Rosseti Centr',
#   '1-01-10214-A',
#   0.5542,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['MRKK',
#   'TQBR',
#   'Россети СК',
#   16.94,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Россети Сев. Кавказ ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   16.92,
#   'SUR',
#   '2025-04-29',
#   2093354170,
#   'RU000A0JPPQ7',
#   'Rosseti Severnyy Kavkaz ao',
#   '1-01-34747-E',
#   16.94,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['MRKP',
#   'TQBR',
#   'РСетиЦП ао',
#   0.3775,
#   10000,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   4,
#   'Россети Центр и Приволжье ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.0001,
#   0.3806,
#   'SUR',
#   '2025-04-29',
#   112697817043,
#   'RU000A0JPN96',
#   'Rosseti Centr i Privoljye ao',
#   '1-01-12665-E',
#   0.3775,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['MRKS',
#   'TQBR',
#   'РсетСиб ао',
#   0.5225,
#   1000,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   4,
#   'Россети Сибирь ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.0005,
#   0.53,
#   'SUR',
#   '2025-04-29',
#   94815163249,
#   'RU000A0JPPF0',
#   'Rosseti Sibir',
#   '1-01-12044-F',
#   0.532,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['MRKU',
#   'TQBR',
#   'Россети Ур',
#   0.3852,
#   10000,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   4,
#   'Россети Урал (ПАО) ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.0002,
#   0.3938,
#   'SUR',
#   '2025-04-29',
#   87430485711,
#   'RU000A0JPPT1',
#   'Rosseti Ural ao',
#   '1-01-32501-D',
#   0.3942,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['MRKV',
#   'TQBR',
#   'РсетВол ао',
#   0.07175,
#   10000,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   5,
#   'Россети Волга ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   5e-05,
#   0.07175,
#   'SUR',
#   '2025-04-29',
#   188307958732,
#   'RU000A0JPPN4',
#   'Rosseti Volga',
#   '1-01-04247-E',
#   0.07175,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['MRKY',
#   'TQBR',
#   'РоссЮг ао',
#   0.0684,
#   10000,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   5,
#   'Россети Юг  (ПАО) ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   5e-05,
#   0.06955,
#   'SUR',
#   '2025-04-29',
#   151641426354,
#   'RU000A0JPPG8',
#   'Rosseti South ao',
#   '1-01-34956-E',
#   0.0684,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['MRKZ',
#   'TQBR',
#   'РСетиСЗ ао',
#   0.061,
#   10000,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   5,
#   'ПАО Россети Северо-Запад ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   5e-05,
#   0.06185,
#   'SUR',
#   '2025-04-29',
#   95785923138,
#   'RU000A0JPPB9',
#   'Rosseti Severo-Zapad',
#   '1-01-03347-D',
#   0.061,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['MRSB',
#   'TQBR',
#   'МордЭнСб',
#   0.732,
#   10000,
#   0.0136,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   'Мордовск.энергсбыт.комп.ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.002,
#   0.74,
#   'SUR',
#   '2025-04-29',
#   1345037710,
#   'RU000A0D9AJ7',
#   'Mordovskaya EnergoSbyt Comp.',
#   '1-01-55055-E',
#   0.732,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['MSNG',
#   'TQBR',
#   '+МосЭнерго',
#   2.2115,
#   1000,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   4,
#   'МосЭнерго акции обыкн.',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.0005,
#   2.227,
#   'SUR',
#   '2025-04-29',
#   39749359700,
#   'RU0008958863',
#   'MosEnrg',
#   '1-01-00085-A',
#   2.2165,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['MSRS',
#   'TQBR',
#   'РСетиМР ао',
#   1.1565,
#   1000,
#   0.5,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   4,
#   'ПАО Россети Моск.рег. ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.0005,
#   1.1695,
#   'SUR',
#   '2025-04-29',
#   48707091574,
#   'RU000A0ET7Y7',
#   'Rosseti Moscow Region',
#   '1-01-65116-D',
#   1.159,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['MSTT',
#   'TQBR',
#   'Мостотрест',
#   133,
#   10,
#   0.14,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ПАО "МОСТОТРЕСТ" ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   135.05,
#   'SUR',
#   '2025-04-29',
#   282215500,
#   'RU0009177331',
#   'Mostotrest',
#   '1-03-02472-A',
#   133,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['MTLR',
#   'TQBR',
#   'Мечел ао',
#   93.16,
#   1,
#   10,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Мечел ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   93.65,
#   'SUR',
#   '2025-04-29',
#   416270745,
#   'RU000A0DKXV5',
#   'Mechel',
#   '1-01-55005-E',
#   93,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['MTLRP',
#   'TQBR',
#   'Мечел ап',
#   94.1,
#   10,
#   10,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Мечел ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   95.2,
#   'SUR',
#   '2025-04-29',
#   138756915,
#   'RU000A0JPV70',
#   'Mechel pref.',
#   '2-01-55005-E',
#   94.6,
#   'SUR',
#   '2',
#   1,
#   '2025-05-02'],
#  ['MTSS',
#   'TQBR',
#   'МТС-ао',
#   217.35,
#   10,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Мобильные ТелеСистемы ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   219.75,
#   'SUR',
#   '2025-04-29',
#   1998381575,
#   'RU0007775219',
#   'MTS',
#   '1-01-04715-A',
#   218.95,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['MVID',
#   'TQBR',
#   'М.видео',
#   106.8,
#   1,
#   10,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   '"М.видео" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   108.45,
#   'SUR',
#   '2025-04-29',
#   179768227,
#   'RU000A0JPGA0',
#   'M.video',
#   '1-02-11700-A',
#   108.2,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['NAUK',
#   'TQBR',
#   'iНПОНаука',
#   498,
#   10,
#   0.2,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'НПО Наука ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   503,
#   'SUR',
#   '2025-04-29',
#   11789500,
#   'RU000A0JRPX9',
#   'NPO Nauka ao',
#   '1-01-04440-A',
#   498,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['NFAZ',
#   'TQBR',
#   'НЕФАЗ',
#   327.5,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'НЕФАЗ ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   333,
#   'SUR',
#   '2025-04-29',
#   8038896,
#   'RU0009115604',
#   'NEFAZ PAO ao',
#   '1-01-30520-D',
#   328.5,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['NKHP',
#   'TQBR',
#   'НКХП ао',
#   819,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'НКХП ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   829,
#   'SUR',
#   '2025-04-29',
#   67597000,
#   'RU000A0BLWD7',
#   'NKHP ao',
#   '1-03-35684-E',
#   817,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['NKNC',
#   'TQBR',
#   'НКНХ ао',
#   89.65,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   '"Нижнекамскнефтехим" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   90.8,
#   'SUR',
#   '2025-04-29',
#   1611256000,
#   'RU0009100507',
#   'Niznekamskneftekhim ao',
#   '1-02-00096-A',
#   89.65,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['NKNCP',
#   'TQBR',
#   'НКНХ ап',
#   70.1,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   '"Нижнекамскнефтехим" ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   70.3,
#   'SUR',
#   '2025-04-29',
#   218983750,
#   'RU0006765096',
#   'Niznekamskneftekhim (pref)',
#   '2-02-00096-A',
#   70.1,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['NKSH',
#   'TQBR',
#   'Нижкамшина',
#   45.85,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Нижнекамскшина ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   46.1,
#   'SUR',
#   '2025-04-29',
#   63731171,
#   'RU0009100515',
#   'Nizhnekamskshina ao',
#   '1-02-55032-D',
#   45.85,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['NLMK',
#   'TQBR',
#   'НЛМК ао',
#   130.24,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ПАО "НЛМК" ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   131.68,
#   'SUR',
#   '2025-04-29',
#   5993227240,
#   'RU0009046452',
#   'NLMK ao',
#   '1-01-00102-A',
#   131.02,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['NMTP',
#   'TQBR',
#   'НМТП ао',
#   9.285,
#   100,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   'НМТП (ПАО) ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.005,
#   9.375,
#   'SUR',
#   '2025-04-29',
#   19259815400,
#   'RU0009084446',
#   'NMTP',
#   '1-01-30251-E',
#   9.375,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['NNSB',
#   'TQBR',
#   'ТНСэнНН ао',
#   3700,
#   1,
#   11.88,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'ТНС энерго Нижний Новг.ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   10,
#   3680,
#   'SUR',
#   '2025-04-29',
#   3919400,
#   'RU000A0ET5A1',
#   'TNS energo Nizhniy-Novgorod ao',
#   '1-01-55072-E',
#   3700,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['NNSBP',
#   'TQBR',
#   'ТНСэнНН ап',
#   1202,
#   1,
#   11.88,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'ТНС энерго Нижний Новг.ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   2,
#   1204,
#   'SUR',
#   '2025-04-29',
#   1063512,
#   'RU000A0ET5B9',
#   'TNS energo Nizhniy Novg. pref',
#   '2-01-55072-E',
#   1202,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['NSVZ',
#   'TQBR',
#   'iНаукаСвяз',
#   307,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Наука-Связь ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   314,
#   'SUR',
#   '2025-04-29',
#   15701562,
#   'RU000A0JQLB6',
#   'Nauka-Svyaz ao',
#   '1-01-12689-A',
#   307,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['NVTK',
#   'TQBR',
#   'Новатэк ао',
#   1214.6,
#   1,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ПАО "НОВАТЭК" ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.2,
#   1225.6,
#   'SUR',
#   '2025-04-29',
#   3036306000,
#   'RU000A0DKVS5',
#   'NOVATEK',
#   '1-02-00268-E',
#   1212.4,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['OGKB',
#   'TQBR',
#   'ОГК-2 ао',
#   0.3617,
#   1000,
#   0.3627,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   4,
#   'ОГК-2 ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.0001,
#   0.3648,
#   'SUR',
#   '2025-04-29',
#   136207331098,
#   'RU000A0JNG55',
#   'OGK-2',
#   '1-02-65105-D',
#   0.3637,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['OKEY',
#   'TQBR',
#   'OKEY-гдр',
#   30.41,
#   10,
#   0,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
# ...
#   None,
#   0.002,
#   0.858,
#   'SUR',
#   '2025-04-29',
#   217961420,
#   'RU000A0D8NH6',
#   'Tambov EnergoSbyt Comp. (pref)',
#   '2-01-65100-D',
#   0.866,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['TATN',
#   'TQBR',
#   'Татнфт 3ао',
#   723.1,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ПАО "Татнефть" ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.1,
#   720.2,
#   'SUR',
#   '2025-04-29',
#   2178690700,
#   'RU0009033591',
#   'Tatneft-3',
#   '1-03-00161-A',
#   718.2,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['TATNP',
#   'TQBR',
#   'Татнфт 3ап',
#   680,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ПАО "Татнефть" ап 3 вып.',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.1,
#   679.1,
#   'SUR',
#   '2025-04-29',
#   147508500,
#   'RU0006944147',
#   'Tatneft (pref)',
#   '2-03-00161-A',
#   678.9,
#   'SUR',
#   '2',
#   1,
#   '2025-05-02'],
#  ['TGKA',
#   'TQBR',
#   'ТГК-1',
#   0.00667,
#   100000,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   6,
#   'ао ПАО "ТГК-1"',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   2e-06,
#   0.006768,
#   'SUR',
#   '2025-04-29',
#   3854341416571,
#   'RU000A0JNUD0',
#   'TGK-1',
#   '1-01-03388-D',
#   0.00674,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['TGKB',
#   'TQBR',
#   'ТГК-2',
#   0.006655,
#   1000000,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   6,
#   'ао ПАО "ТГК-2"',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   5e-06,
#   0.00664,
#   'SUR',
#   '2025-04-29',
#   1458404850747,
#   'RU000A0JNGS7',
#   'TGK-2',
#   '1-01-10420-A',
#   0.006655,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['TGKBP',
#   'TQBR',
#   'ТГК-2 ап',
#   0.01024,
#   100000,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   5,
#   'ап ПАО "ТГК-2"',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   1e-05,
#   0.01033,
#   'SUR',
#   '2025-04-29',
#   16500533681,
#   'RU000A0JNGT5',
#   'TGK-2 pref',
#   '2-01-10420-A',
#   0.01024,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['TGKN',
#   'TQBR',
#   'ТГК-14',
#   0.00793,
#   100000,
#   0.001,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   5,
#   'ао ПАО "ТГК-14"',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   1e-05,
#   0.00798,
#   'SUR',
#   '2025-04-29',
#   1357945609114,
#   'RU000A0H1ES3',
#   'TGK-14',
#   '1-01-22451-F',
#   0.00793,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['TNSE',
#   'TQBR',
#   'ТНСэнрг ао',
#   2240,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'ПАО ГК "ТНС энерго" ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   5,
#   2235,
#   'SUR',
#   '2025-04-29',
#   13668239,
#   'RU000A0JUCQ5',
#   'PAO GK "TNS energo" ao',
#   '1-01-15521-A',
#   2240,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['TORS',
#   'TQBR',
#   'РСТомск ао',
#   0.584,
#   10000,
#   0.4916,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   'ао ПАО "Россети Томск"',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.002,
#   0.584,
#   'SUR',
#   '2025-04-29',
#   3819315580,
#   'RU000A0ETZF2',
#   'PAO Rosseti Tomsk ao',
#   '1-01-50128-A',
#   0.586,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['TORSP',
#   'TQBR',
#   'РСТомск ап',
#   0.423,
#   10000,
#   0.4916,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   'ап ПАО "Россети Томск"',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.001,
#   0.425,
#   'SUR',
#   '2025-04-29',
#   576693000,
#   'RU000A0ETZM8',
#   'PAO Rosseti Tomsk ap',
#   '2-01-50128-A',
#   0.423,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['TRMK',
#   'TQBR',
#   'ТМК ао',
#   110.58,
#   10,
#   10,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ПАО ТМК',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   111.42,
#   'SUR',
#   '2025-04-29',
#   1052000000,
#   'RU000A0B6NK6',
#   'TMK ao',
#   '1-01-29031-H',
#   110.74,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['TRNFP',
#   'TQBR',
#   'Транснф ап',
#   1288.2,
#   1,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Транснефть ПАО акц.пр.',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.2,
#   1292.8,
#   'SUR',
#   '2025-04-29',
#   155487500,
#   'RU0009091573',
#   'Transneft (pref)',
#   '2-01-00206-A',
#   1288.4,
#   'SUR',
#   '2',
#   1,
#   '2025-05-02'],
#  ['TTLK',
#   'TQBR',
#   'Таттел. ао',
#   0.7605,
#   1000,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   4,
#   '"Таттелеком" ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.0005,
#   0.7725,
#   'SUR',
#   '2025-04-29',
#   20843976400,
#   'RU000A0HM5C1',
#   'Tattelekom',
#   '1-02-50049-A',
#   0.7605,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['TUZA',
#   'TQBR',
#   'ТЗА ао',
#   175,
#   10,
#   10,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Туймаз. завод автобетоновозов',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   177,
#   'SUR',
#   '2025-04-29',
#   8220000,
#   'RU000A0HL7A2',
#   'Tuimaz. Zavod Avtobetonovozov',
#   '1-01-30455-D',
#   175,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['UGLD',
#   'TQBR',
#   'ЮГК',
#   0.6602,
#   1000,
#   0.001,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   4,
#   'ЮГК',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.0001,
#   0.6634,
#   'SUR',
#   '2025-04-29',
#   222778849052,
#   'RU000A0JPP37',
#   'UGC',
#   '1-02-33010-D',
#   0.6612,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['UKUZ',
#   'TQBR',
#   'ЮжКузб. ао',
#   1044,
#   1,
#   0.04,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Южный Кузбасс ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   2,
#   1048,
#   'SUR',
#   '2025-04-29',
#   36149002,
#   'RU0005294775',
#   'Uzhnyi Kuzbass',
#   '1-02-10591-F',
#   1044,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['UNAC',
#   'TQBR',
#   'iАвиастКао',
#   0.62,
#   1000,
#   0.27,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   4,
#   'Об.авиастр.корп. ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.0005,
#   0.6305,
#   'SUR',
#   '2025-04-29',
#   994436434417,
#   'RU000A0JPLZ7',
#   'Ob.aviastroitelnaya korp.',
#   '1-02-55306-E',
#   0.6245,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['UNKL',
#   'TQBR',
#   'ЮУНК ао',
#   5460,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Южно-Уральский никел. комб. ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   10,
#   5500,
#   'SUR',
#   '2025-04-29',
#   599737,
#   'RU0004887991',
#   'Uzhno-Uralskiy nikel. komb. ao',
#   '1-01-00197-A',
#   5450,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['UPRO',
#   'TQBR',
#   'Юнипро ао',
#   1.768,
#   1000,
#   0.4,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   'Юнипро ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.001,
#   1.795,
#   'SUR',
#   '2025-04-29',
#   63048706145,
#   'RU000A0JNGA5',
#   'Unipro PAO ao',
#   '1-02-65104-D',
#   1.782,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['URKZ',
#   'TQBR',
#   'УрКузница',
#   33900,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'ПАО "Уральская кузница" ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   100,
#   34000,
#   'SUR',
#   '2025-04-29',
#   547761,
#   'RU000A0JPFY2',
#   'Uralskaya kuznica ao',
#   '1-01-32341-D',
#   33900,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['USBN',
#   'TQBR',
#   'УралСиб ао',
#   0.1613,
#   10000,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   4,
#   'БАНК УРАЛСИБ ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.0001,
#   0.162,
#   'SUR',
#   '2025-04-29',
#   360134697357,
#   'RU0006929536',
#   'BANK URALSIB ao',
#   '10200030B',
#   0.1609,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['UTAR',
#   'TQBR',
#   'ЮТэйр ао',
#   12.9,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Авиакомпания "ЮТэйр" (ПАО) ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   12.97,
#   'SUR',
#   '2025-04-29',
#   7896123268,
#   'RU0007661385',
#   'UTAir Aviacompany',
#   '1-01-00077-F',
#   12.9,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['UWGN',
#   'TQBR',
#   'ОВК ао',
#   42.08,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ПАО НПК ОВК ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   42.78,
#   'SUR',
#   '2025-04-29',
#   2905885544,
#   'RU000A0JVBT9',
#   'OVK ao',
#   '1-01-82031-H',
#   42.4,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['VEON-RX',
#   'TQBR',
#   'VEON',
#   84.9,
#   10,
#   0.001,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'VEON Ltd. ORD SHS',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   87.6,
#   'USD',
#   '2025-04-29',
#   1749127404,
#   'BMG9349W1038',
#   'VEON Ltd. ORD SHS',
#   None,
#   84.9,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['VGSB',
#   'TQBR',
#   'ВолгЭнСб',
#   11.1,
#   1000,
#   0.12,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   '"Волгоград.энергосбыткомп" ПАО',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   11,
#   'SUR',
#   '2025-04-29',
#   319595965,
#   'RU000A0D8L73',
#   'Volgograd Energo Sbyt',
#   '1-01-65103-D',
#   11.1,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['VGSBP',
#   'TQBR',
#   'ВолгЭнСб-п',
#   11.02,
#   1000,
#   0.12,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   '"Волгоград.энергосбыткомп" ПАО',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   11.04,
#   'SUR',
#   '2025-04-29',
#   80499134,
#   'RU000A0D8L57',
#   'Volgograd Energo Sbyt (pref)',
#   '2-01-65103-D',
#   11.02,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['VJGZ',
#   'TQBR',
#   'Варьеган',
#   2585,
#   1,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'ННК-Варьеганнефтегаз ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   5,
#   2575,
#   'SUR',
#   '2025-04-29',
#   18091110,
#   'RU0009046460',
#   "Var'eganneftegaz ao",
#   '1-01-00017-A',
#   2585,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['VJGZP',
#   'TQBR',
#   'Варьеган-п',
#   1560,
#   1,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'ННК-Варьеганнефтегаз ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   5,
#   1575,
#   'SUR',
#   '2025-04-29',
#   5883050,
#   'RU0007964789',
#   "Var'eganneftegaz ap",
#   '2-01-00017-A',
#   1565,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['VKCO',
#   'TQBR',
#   'МКПАО "ВК"',
#   263.8,
#   1,
#   0.000450595,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Международная компания ПАО ВК',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.1,
#   267.6,
#   'SUR',
#   '2025-04-29',
#   227874940,
#   'RU000A106YF0',
#   'VK International Public JS Com',
#   '1-01-16753-A',
#   266.7,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['VLHZ',
#   'TQBR',
#   'ВХЗ-ао',
#   184.4,
#   10,
#   20,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Владимирский химич.з-д(ПАО) ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.2,
#   186.2,
#   'SUR',
#   '2025-04-29',
#   5005605,
#   'RU0007984761',
#   'VHZ',
#   '1-02-04847-A',
#   184.4,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['VRSB',
#   'TQBR',
#   'ТНСэнВорон',
#   397,
#   10,
#   0.4,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ТНС энерго Воронеж ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   397,
#   'SUR',
#   '2025-04-29',
#   56151024,
#   'RU000A0DPG67',
#   'TNS energo Voroneg ao',
#   '1-01-55029-E',
#   397,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['VRSBP',
#   'TQBR',
#   'ТНСэнВор-п',
#   127.8,
#   10,
#   0.4,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ТНС энерго Воронеж ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.2,
#   127.6,
#   'SUR',
#   '2025-04-29',
#   18716678,
#   'RU000A0DPG75',
#   'TNS energo Voroneg ap',
#   '2-01-55029-E',
#   127.8,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['VSEH',
#   'TQBR',
#   'ВИ.ру',
#   90.35,
#   1,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ВИ.ру',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   90.6,
#   'SUR',
#   '2025-04-29',
#   500000000,
#   'RU000A108K09',
#   'VI.ru',
#   '1-01-06636-G',
#   90.6,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['VSMO',
#   'TQBR',
#   'ВСМПО-АВСМ',
#   33840,
#   1,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Корп. ВСМПО-АВИСМА (ПАО) ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   20,
#   34580,
#   'SUR',
#   '2025-04-29',
#   11529538,
#   'RU0009100291',
#   'Corp. VSMPO-AVISMA ao',
#   '1-01-30202-D',
#   35180,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['VSYD',
#   'TQBR',
#   'ВыбСудЗ ао',
#   11450,
#   1,
#   0.5,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Выборгский Суд.Завод ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   50,
#   11450,
#   'SUR',
#   '2025-04-29',
#   1891250,
#   'RU0006334372',
#   'Viborgskii sudostr. Zavod ao',
#   '1-01-02203-D',
#   11450,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['VSYDP',
#   'TQBR',
#   'ВыбСудЗ ап',
#   8400,
#   1,
#   0.5,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Выборгский Суд.Завод ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   50,
#   8300,
#   'SUR',
#   '2025-04-29',
#   51839,
#   'RU0006334380',
#   'Viborgskii sudostr. Zavod ap',
#   '2-01-02203-D',
#   8350,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['VTBR',
#   'TQBR',
#   'ВТБ ао',
#   97.3,
#   1,
#   50,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ао ПАО Банк ВТБ',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   98.27,
#   'SUR',
#   '2025-04-29',
#   5369933893,
#   'RU000A0JP5V6',
#   'VTB',
#   '10401000B',
#   97.06,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['WTCM',
#   'TQBR',
#   'ЦМТ ао',
#   12.96,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   '"Центр междун. торговли"ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   13.1,
#   'SUR',
#   '2025-04-29',
#   1083000000,
#   'RU0008137070',
#   'CMT',
#   '1-01-01837-A',
#   12.96,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['WTCMP',
#   'TQBR',
#   'ЦМТ ап',
#   10.12,
#   100,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   '"Центр междун. торговли"ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.02,
#   10.14,
#   'SUR',
#   '2025-04-29',
#   162000000,
#   'RU0008137088',
#   'CMT (pref)',
#   '2-01-01837-A',
#   10.12,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['WUSH',
#   'TQBR',
#   'iВУШХолднг',
#   179.54,
#   1,
#   0.01,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ВУШ Холдинг ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   181.79,
#   'SUR',
#   '2025-04-29',
#   111382432,
#   'RU000A105EX7',
#   'WHOOSH Holding',
#   '1-01-03292-G',
#   180.61,
#   'SUR',
#   '1',
#   2,
#   '2025-05-02'],
#  ['X5',
#   'TQBR',
#   'КЦ ИКС 5',
#   3357,
#   1,
#   1164.26,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'Корпоративный центр ИКС 5',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   3371,
#   'SUR',
#   '2025-04-29',
#   271572872,
#   'RU000A108X38',
#   'X5 Corporate Center',
#   '1-01-16812-A',
#   3351,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['YAKG',
#   'TQBR',
#   'ЯТЭК ао',
#   59.4,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Якутская топл.-энерг. комп. ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   59.75,
#   'SUR',
#   '2025-04-29',
#   826919375,
#   'RU0007796819',
#   'YaTEK ao',
#   '1-01-20510-F',
#   59.4,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['YDEX',
#   'TQBR',
#   'ЯНДЕКС',
#   4155,
#   1,
#   0.4,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'МКПАО ЯНДЕКС',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   4214.5,
#   'SUR',
#   '2025-04-29',
#   390548277,
#   'RU000A107T19',
#   'YANDEX',
#   '1-01-16777-A',
#   4191,
#   'SUR',
#   '1',
#   1,
#   '2025-05-02'],
#  ['YKEN',
#   'TQBR',
#   'Якутскэнрг',
#   0.497,
#   10000,
#   2.22,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   'АК "Якутскэнерго" (ПАО) ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.001,
#   0.492,
#   'SUR',
#   '2025-04-29',
#   10187741424,
#   'RU0009257075',
#   'YakutskEnergo',
#   '1-01-00304-A',
#   0.495,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['YKENP',
#   'TQBR',
#   'Якутскэн-п',
#   0.372,
#   10000,
#   2.22,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   3,
#   'АК "Якутскэнерго" (ПАО) ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.001,
#   0.371,
#   'SUR',
#   '2025-04-29',
#   1332635125,
#   'RU0007796827',
#   'YakutskEnergo ap',
#   '2-01-00304-A',
#   0.37,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['YRSB',
#   'TQBR',
#   'ТНСэнЯр',
#   724,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'ТНС энерго Ярославль ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   2,
#   724,
#   'SUR',
#   '2025-04-29',
#   17143584,
#   'RU000A0D8760',
#   "TNS energo Yaroslavl' ao",
#   '1-01-50099-A',
#   724,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['YRSBP',
#   'TQBR',
#   'ТНСэнЯр-п',
#   197,
#   10,
#   1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   1,
#   'ТНС энерго Ярославль ПАО ап',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.5,
#   201,
#   'SUR',
#   '2025-04-29',
#   4507320,
#   'RU000A0D88B3',
#   "TNS energo Yaroslavl' (pref)",
#   '2-01-50099-A',
#   197,
#   'SUR',
#   '2',
#   3,
#   '2025-05-02'],
#  ['ZAYM',
#   'TQBR',
#   'Займер ао',
#   144.2,
#   10,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'Займер ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.05,
#   145.9,
#   'SUR',
#   '2025-04-29',
#   100000000,
#   'RU000A107RM8',
#   'Zaymer',
#   '1-01-16767-A',
#   144.9,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['ZILL',
#   'TQBR',
#   'ЗИЛ ао',
#   3950,
#   1,
#   1000,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   0,
#   'Завод им. И.А.Лихачева ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   5,
#   4000,
#   'SUR',
#   '2025-04-29',
#   2659962,
#   'RU0009086193',
#   'ZIL ao',
#   '1-02-00036-A',
#   3950,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02'],
#  ['ZVEZ',
#   'TQBR',
#   'ЗВЕЗДА ао',
#   7.68,
#   1000,
#   0.1,
#   'A',
#   'Т+: Акции и ДР - безадрес.',
#   2,
#   'ЗВЕЗДА ПАО ао',
#   None,
#   'FNDT',
#   'EQIN',
#   None,
#   0.01,
#   7.68,
#   'SUR',
#   '2025-04-29',
#   562020480,
#   'RU0009091300',
#   'Zvezda ao',
#   '1-01-00169-D',
#   7.68,
#   'SUR',
#   '1',
#   3,
#   '2025-05-02']]

# %%
d = json.loads(json_data)
df = pd.DataFrame(columns=d["securities"]["columns"])

for i in range(len(d["securities"]["data"])):
    df.loc[i] = d["securities"]["data"][i]

df
# Out:
#      SECID BOARDID   SHORTNAME  PREVPRICE LOTSIZE  FACEVALUE STATUS  \
# 0     ABIO    TQBR  iАРТГЕН ао      84.64      10       0.10      A
# 1     ABRD    TQBR  АбрауДюрсо     187.40      10       1.00      A
# 2     AFKS    TQBR  Система ао      15.42     100       0.09      A
# 3     AFLT    TQBR    Аэрофлот      70.79      10       1.00      A
# 4     AGRO    TQBR    AGRO-гдр    1083.80       1       0.00      N
# ..     ...     ...         ...        ...     ...        ...    ...
# 254   YRSB    TQBR     ТНСэнЯр     724.00      10       1.00      A
# 255  YRSBP    TQBR   ТНСэнЯр-п     197.00      10       1.00      A
# 256   ZAYM    TQBR   Займер ао     144.20      10       0.10      A
# 257   ZILL    TQBR      ЗИЛ ао    3950.00       1    1000.00      A
# 258   ZVEZ    TQBR   ЗВЕЗДА ао       7.68    1000       0.10      A
#
#                       BOARDNAME DECIMALS                        SECNAME  ...  \
# 0    Т+: Акции и ДР - безадрес.        2                   ПАО "Артген"  ...
# 1    Т+: Акции и ДР - безадрес.        1             Абрау-Дюрсо ПАО ао  ...
# 2    Т+: Акции и ДР - безадрес.        3           АФК "Система" ПАО ао  ...
# 3    Т+: Акции и ДР - безадрес.        2   Аэрофлот-росс.авиалин(ПАО)ао  ...
# 4    Т+: Акции и ДР - безадрес.        1       ГДР ROS AGRO PLC ORD SHS  ...
# ..                          ...      ...                            ...  ...
# 254  Т+: Акции и ДР - безадрес.        0    ТНС энерго Ярославль ПАО ао  ...
# 255  Т+: Акции и ДР - безадрес.        1    ТНС энерго Ярославль ПАО ап  ...
# 256  Т+: Акции и ДР - безадрес.        2                      Займер ао  ...
# 257  Т+: Акции и ДР - безадрес.        0  Завод им. И.А.Лихачева ПАО ао  ...
# 258  Т+: Акции и ДР - безадрес.        2                  ЗВЕЗДА ПАО ао  ...
#
#        PREVDATE   ISSUESIZE          ISIN                       LATNAME  \
# 0    2025-04-29    92645451  RU000A0JNAB6                     ARTGEN ao
# 1    2025-04-29    98000184  RU000A0JS5T7                Abrau-Durso ao
# 2    2025-04-29  9650000000  RU000A0DQZE3                   AFK Sistema
# 3    2025-04-29  3975771215  RU0009062285                      Aeroflot
# 4    2025-04-29           0  US7496552057      GDR ROS AGRO PLC ORD SHS
# ..          ...         ...           ...                           ...
# 254  2025-04-29    17143584  RU000A0D8760      TNS energo Yaroslavl' ao
# 255  2025-04-29     4507320  RU000A0D88B3  TNS energo Yaroslavl' (pref)
# 256  2025-04-29   100000000  RU000A107RM8                        Zaymer
# 257  2025-04-29     2659962  RU0009086193                        ZIL ao
# 258  2025-04-29   562020480  RU0009091300                     Zvezda ao
#
#         REGNUMBER  PREVLEGALCLOSEPRICE CURRENCYID SECTYPE LISTLEVEL  \
# 0    1-01-08902-A                85.28        SUR       1         2
# 1    1-02-12500-A               187.40        SUR       1         3
# 2    1-05-01669-A                15.48        SUR       1         1
# 3    1-01-00010-A                71.01        SUR       1         1
# 4            None              1085.20        SUR       D         3
# ..            ...                  ...        ...     ...       ...
# 254  1-01-50099-A               724.00        SUR       1         3
# 255  2-01-50099-A               197.00        SUR       2         3
# 256  1-01-16767-A               144.90        SUR       1         3
# 257  1-02-00036-A              3950.00        SUR       1         3
# 258  1-01-00169-D                 7.68        SUR       1         3
#
#      SETTLEDATE
# 0    2025-05-02
# 1    2025-05-02
# 2    2025-05-02
# 3    2025-05-02
# 4    2025-05-02
# ..          ...
# 254  2025-05-02
# 255  2025-05-02
# 256  2025-05-02
# 257  2025-05-02
# 258  2025-05-02
#
# [259 rows x 27 columns]
